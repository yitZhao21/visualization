# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots(figsize = (5,3))
ax.barh(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y, bins=30, color='skyblue', edgecolor='black')
# Out:
# (array([1., 2., 1., 2., 2., 2., 2., 0., 0., 0., 2., 3., 2., 1., 4., 3., 2.,
#         1., 1., 0., 3., 0., 1., 2., 7., 0., 2., 1., 1., 2.]),
#  array([ 6.        ,  9.06666667, 12.13333333, 15.2       , 18.26666667,
#         21.33333333, 24.4       , 27.46666667, 30.53333333, 33.6       ,
#         36.66666667, 39.73333333, 42.8       , 45.86666667, 48.93333333,
#         52.        , 55.06666667, 58.13333333, 61.2       , 64.26666667,
#         67.33333333, 70.4       , 73.46666667, 76.53333333, 79.6       ,
#         82.66666667, 85.73333333, 88.8       , 91.86666667, 94.93333333,
#         98.        ]),
#  <BarContainer object of 30 artists>)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
font1 = {'family':'sans-serif','color': 'blue','size':20}
font2 = {'family': 'monospace', 'color': 'green','size':14}

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc = 'left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start',fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5,3))

ax.plot(x,
        y,
        marker = '*',
        color = 'indigo',
        linestyle = '--',
        linewidth = 2)
fig.show()
# Out:
# C:\Users\18221\AppData\Local\Temp\ipykernel_34076\3977001789.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker='*', color = 'indigo', linestyle = '--', # NEW ADDITIONS
        linewidth = 2) # NEW ADDITIONS
fig.show()
# Out:
# C:\Users\18221\AppData\Local\Temp\ipykernel_15808\2995402858.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3)) # color being the new addition
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
fig.show()
# Out:
# C:\Users\18221\AppData\Local\Temp\ipykernel_15808\2059798911.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
ax.plot(x,y,marker='*', markersize = 12, # NEW ADDITIONS 
        color = '#7425b9', linestyle = '--', linewidth = 2, markeredgecolor = '#fa9359', # NEW ADDITIONS 
        markerfacecolor = '#fa9359' ) # NEW ADDITIONS

# %%
fig, ax = plt.subplots(figsize=(5, 3)) # color being the new addition
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
ax.grid(axis = 'y')
fig.show()
# Out:
# C:\Users\18221\AppData\Local\Temp\ipykernel_15808\863878191.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3)) # color being the new addition
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
ax.grid(axis = 'y', color = 'blue', linewidth = 2, linestyle = '-.')
fig.show()
# Out:
# C:\Users\18221\AppData\Local\Temp\ipykernel_15808\1556950022.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
